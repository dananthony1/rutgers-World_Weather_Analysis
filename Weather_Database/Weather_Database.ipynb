# %%
# Import Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random

import requests
import time
from datetime import datetime

from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

from citipy import citipy

import timeit

# %%
# %timeit np.random.uniform(-90.000,90.000, size=2000)
# Out:
# 12.6 µs ± 112 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90,90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 2000
# %timeit latitudes(2000)
# Out:
# 1.6 ms ± 8.46 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

# %%
cities =[]
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 760

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": weather_description})
        
# If an error is experienced, skip the city.

    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 1 | geraldton
# Processing Record 5 of Set 1 | sept-iles
# Processing Record 6 of Set 1 | upernavik
# Processing Record 7 of Set 1 | yendi
# Processing Record 8 of Set 1 | pisco
# Processing Record 9 of Set 1 | clyde river
# Processing Record 10 of Set 1 | klaksvik
# Processing Record 11 of Set 1 | esperance
# Processing Record 12 of Set 1 | codrington
# Processing Record 13 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 1 | new norfolk
# Processing Record 15 of Set 1 | hasaki
# Processing Record 16 of Set 1 | provideniya
# Processing Record 17 of Set 1 | puerto ayora
# Processing Record 18 of Set 1 | jinji
# Processing Record 19 of Set 1 | russkaya polyana
# Processing Record 20 of Set 1 | torbay
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | jiddah
# City not found. Skipping...
# Processing Record 23 of Set 1 | butaritari
# Processing Record 24 of Set 1 | mangrol
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | arraial do cabo
# Processing Record 27 of Set 1 | xining
# Processing Record 28 of Set 1 | mahebourg
# Processing Record 29 of Set 1 | north bend
# Processing Record 30 of Set 1 | yellowknife
# Processing Record 31 of Set 1 | nelson bay
# Processing Record 32 of Set 1 | zemio
# Processing Record 33 of Set 1 | ust-maya
# Processing Record 34 of Set 1 | bredasdorp
# Processing Record 35 of Set 1 | namibe
# Processing Record 36 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 1 | sovetskiy
# Processing Record 38 of Set 1 | victor harbor
# Processing Record 39 of Set 1 | nikolskoye
# Processing Record 40 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 1 | kapaa
# Processing Record 42 of Set 1 | albany
# Processing Record 43 of Set 1 | nkowakowa
# Processing Record 44 of Set 1 | redcliffe
# Processing Record 45 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 1 | kaitangata
# Processing Record 47 of Set 1 | gorontalo
# Processing Record 48 of Set 1 | sao filipe
# Processing Record 49 of Set 1 | hobart
# Processing Record 50 of Set 1 | saldanha
# Processing Record 1 of Set 2 | abashiri
# Processing Record 2 of Set 2 | sibolga
# Processing Record 3 of Set 2 | gospic
# Processing Record 4 of Set 2 | solovetskiy
# City not found. Skipping...
# Processing Record 5 of Set 2 | hilo
# Processing Record 6 of Set 2 | swift current
# Processing Record 7 of Set 2 | ribeira grande
# Processing Record 8 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 2 | jamestown
# Processing Record 10 of Set 2 | novoagansk
# Processing Record 11 of Set 2 | ales
# Processing Record 12 of Set 2 | anisoc
# Processing Record 13 of Set 2 | mayo
# Processing Record 14 of Set 2 | chokurdakh
# Processing Record 15 of Set 2 | port elizabeth
# Processing Record 16 of Set 2 | mar del plata
# Processing Record 17 of Set 2 | olafsvik
# Processing Record 18 of Set 2 | davidson
# Processing Record 19 of Set 2 | thompson
# Processing Record 20 of Set 2 | port alfred
# Processing Record 21 of Set 2 | matara
# Processing Record 22 of Set 2 | meridian
# Processing Record 23 of Set 2 | saskylakh
# Processing Record 24 of Set 2 | hithadhoo
# Processing Record 25 of Set 2 | chimbote
# Processing Record 26 of Set 2 | gurgan
# City not found. Skipping...
# Processing Record 27 of Set 2 | hirara
# Processing Record 28 of Set 2 | hualmay
# Processing Record 29 of Set 2 | fukue
# Processing Record 30 of Set 2 | mancio lima
# Processing Record 31 of Set 2 | ancud
# Processing Record 32 of Set 2 | vaini
# Processing Record 33 of Set 2 | lima
# Processing Record 34 of Set 2 | kutum
# Processing Record 35 of Set 2 | buchanan
# Processing Record 36 of Set 2 | rognan
# Processing Record 37 of Set 2 | tuktoyaktuk
# Processing Record 38 of Set 2 | asau
# Processing Record 39 of Set 2 | ushuaia
# Processing Record 40 of Set 2 | lagoa
# Processing Record 41 of Set 2 | bluff
# Processing Record 42 of Set 2 | victoria
# Processing Record 43 of Set 2 | valparaiso
# Processing Record 44 of Set 2 | tamiahua
# Processing Record 45 of Set 2 | asfi
# Processing Record 46 of Set 2 | talah
# City not found. Skipping...
# Processing Record 47 of Set 2 | apatity
# Processing Record 48 of Set 2 | aklavik
# Processing Record 49 of Set 2 | castro
# Processing Record 50 of Set 2 | mapastepec
# Processing Record 1 of Set 3 | avarua
# Processing Record 2 of Set 3 | mikuni
# Processing Record 3 of Set 3 | lorengau
# Processing Record 4 of Set 3 | katsuura
# Processing Record 5 of Set 3 | lebu
# Processing Record 6 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 3 | chingirlau
# Processing Record 8 of Set 3 | maunabo
# Processing Record 9 of Set 3 | mana
# Processing Record 10 of Set 3 | jiuquan
# Processing Record 11 of Set 3 | waingapu
# Processing Record 12 of Set 3 | yulara
# Processing Record 13 of Set 3 | muros
# Processing Record 14 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 15 of Set 3 | port hedland
# Processing Record 16 of Set 3 | cidreira
# Processing Record 17 of Set 3 | busselton
# Processing Record 18 of Set 3 | new glasgow
# Processing Record 19 of Set 3 | mount gambier
# Processing Record 20 of Set 3 | gorkovskiy
# Processing Record 21 of Set 3 | tevaitoa
# Processing Record 22 of Set 3 | beidao
# Processing Record 23 of Set 3 | cherskiy
# Processing Record 24 of Set 3 | nizhniy tsasuchey
# Processing Record 25 of Set 3 | nucsoara
# Processing Record 26 of Set 3 | garden city
# Processing Record 27 of Set 3 | husavik
# Processing Record 28 of Set 3 | san vicente
# Processing Record 29 of Set 3 | la ronge
# Processing Record 30 of Set 3 | san rafael
# Processing Record 31 of Set 3 | caravelas
# Processing Record 32 of Set 3 | chake chake
# Processing Record 33 of Set 3 | kotido
# Processing Record 34 of Set 3 | develi
# Processing Record 35 of Set 3 | sassandra
# Processing Record 36 of Set 3 | bathsheba
# Processing Record 37 of Set 3 | hermanus
# Processing Record 38 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 3 | lander
# Processing Record 40 of Set 3 | grand-santi
# Processing Record 41 of Set 3 | salalah
# Processing Record 42 of Set 3 | qaanaaq
# Processing Record 43 of Set 3 | hovd
# Processing Record 44 of Set 3 | tasiilaq
# Processing Record 45 of Set 3 | aljezur
# Processing Record 46 of Set 3 | paradwip
# City not found. Skipping...
# Processing Record 47 of Set 3 | port hardy
# Processing Record 48 of Set 3 | alta floresta
# Processing Record 49 of Set 3 | vostok
# Processing Record 50 of Set 3 | sambava
# Processing Record 1 of Set 4 | sunrise manor
# Processing Record 2 of Set 4 | whitehorse
# Processing Record 3 of Set 4 | koslan
# Processing Record 4 of Set 4 | fugen
# Processing Record 5 of Set 4 | les cayes
# Processing Record 6 of Set 4 | igarka
# Processing Record 7 of Set 4 | grindavik
# Processing Record 8 of Set 4 | port keats
# Processing Record 9 of Set 4 | pangnirtung
# Processing Record 10 of Set 4 | eyl
# Processing Record 11 of Set 4 | iqaluit
# Processing Record 12 of Set 4 | ilulissat
# Processing Record 13 of Set 4 | kapit
# Processing Record 14 of Set 4 | ust-omchug
# Processing Record 15 of Set 4 | crab hill
# City not found. Skipping...
# Processing Record 16 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 4 | gimli
# Processing Record 18 of Set 4 | norman wells
# Processing Record 19 of Set 4 | kahului
# Processing Record 20 of Set 4 | huarmey
# Processing Record 21 of Set 4 | chuy
# Processing Record 22 of Set 4 | hammerfest
# Processing Record 23 of Set 4 | bethel
# Processing Record 24 of Set 4 | palmer
# Processing Record 25 of Set 4 | baykit
# Processing Record 26 of Set 4 | coromandel
# Processing Record 27 of Set 4 | kieta
# Processing Record 28 of Set 4 | tiksi
# Processing Record 29 of Set 4 | akdagmadeni
# Processing Record 30 of Set 4 | ahipara
# Processing Record 31 of Set 4 | labuhan
# Processing Record 32 of Set 4 | tessalit
# Processing Record 33 of Set 4 | revelstoke
# Processing Record 34 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 4 | hailar
# Processing Record 36 of Set 4 | san rafael del sur
# Processing Record 37 of Set 4 | great yarmouth
# Processing Record 38 of Set 4 | west wendover
# Processing Record 39 of Set 4 | narsaq
# Processing Record 40 of Set 4 | satun
# Processing Record 41 of Set 4 | lompoc
# Processing Record 42 of Set 4 | chara
# Processing Record 43 of Set 4 | ayagoz
# Processing Record 44 of Set 4 | pevek
# Processing Record 45 of Set 4 | havelock
# Processing Record 46 of Set 4 | kottagudem
# Processing Record 47 of Set 4 | chapais
# Processing Record 48 of Set 4 | puerto cabezas
# Processing Record 49 of Set 4 | katakwi
# Processing Record 50 of Set 4 | buraydah
# Processing Record 1 of Set 5 | dikson
# Processing Record 2 of Set 5 | emerald
# Processing Record 3 of Set 5 | manicore
# Processing Record 4 of Set 5 | antofagasta
# Processing Record 5 of Set 5 | lake cowichan
# Processing Record 6 of Set 5 | bethanien
# Processing Record 7 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 8 of Set 5 | genhe
# Processing Record 9 of Set 5 | cayenne
# Processing Record 10 of Set 5 | bac lieu
# Processing Record 11 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 5 | chumikan
# Processing Record 13 of Set 5 | sredec
# City not found. Skipping...
# Processing Record 14 of Set 5 | vyazniki
# Processing Record 15 of Set 5 | saint-philippe
# Processing Record 16 of Set 5 | cape town
# Processing Record 17 of Set 5 | georgetown
# Processing Record 18 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 19 of Set 5 | luanda
# Processing Record 20 of Set 5 | sao jose da coroa grande
# Processing Record 21 of Set 5 | barcelos
# Processing Record 22 of Set 5 | fortuna
# Processing Record 23 of Set 5 | mareeba
# Processing Record 24 of Set 5 | san nicolas
# Processing Record 25 of Set 5 | talnakh
# Processing Record 26 of Set 5 | russell
# Processing Record 27 of Set 5 | tiarei
# Processing Record 28 of Set 5 | sankt polten
# Processing Record 29 of Set 5 | evensk
# Processing Record 30 of Set 5 | yarada
# Processing Record 31 of Set 5 | coquimbo
# Processing Record 32 of Set 5 | bowen
# Processing Record 33 of Set 5 | el progreso
# Processing Record 34 of Set 5 | kefamenanu
# Processing Record 35 of Set 5 | tahoua
# Processing Record 36 of Set 5 | hamilton
# Processing Record 37 of Set 5 | constitucion
# Processing Record 38 of Set 5 | sao joao da barra
# Processing Record 39 of Set 5 | saint-augustin
# Processing Record 40 of Set 5 | vila
# Processing Record 41 of Set 5 | acari
# Processing Record 42 of Set 5 | basco
# Processing Record 43 of Set 5 | flinders
# Processing Record 44 of Set 5 | thunder bay
# Processing Record 45 of Set 5 | mamallapuram
# Processing Record 46 of Set 5 | ponta do sol
# Processing Record 47 of Set 5 | carutapera
# Processing Record 48 of Set 5 | vao
# Processing Record 49 of Set 5 | okha
# Processing Record 50 of Set 5 | taga
# Processing Record 1 of Set 6 | bengkulu
# Processing Record 2 of Set 6 | serenje
# Processing Record 3 of Set 6 | margate
# Processing Record 4 of Set 6 | lar gerd
# City not found. Skipping...
# Processing Record 5 of Set 6 | asuncion
# Processing Record 6 of Set 6 | murdochville
# Processing Record 7 of Set 6 | vicente guerrero
# Processing Record 8 of Set 6 | doha
# Processing Record 9 of Set 6 | nanortalik
# Processing Record 10 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 11 of Set 6 | rurrenabaque
# Processing Record 12 of Set 6 | touros
# Processing Record 13 of Set 6 | gonaives
# Processing Record 14 of Set 6 | kavieng
# Processing Record 15 of Set 6 | marsa matruh
# Processing Record 16 of Set 6 | sistranda
# Processing Record 17 of Set 6 | estelle
# Processing Record 18 of Set 6 | havre
# Processing Record 19 of Set 6 | batemans bay
# Processing Record 20 of Set 6 | naliya
# Processing Record 21 of Set 6 | west helena
# Processing Record 22 of Set 6 | namatanai
# Processing Record 23 of Set 6 | brewster
# Processing Record 24 of Set 6 | svetlaya
# Processing Record 25 of Set 6 | kalabo
# Processing Record 26 of Set 6 | lyaskelya
# Processing Record 27 of Set 6 | pascagoula
# Processing Record 28 of Set 6 | douentza
# Processing Record 29 of Set 6 | kiama
# Processing Record 30 of Set 6 | turukhansk
# Processing Record 31 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 32 of Set 6 | nome
# Processing Record 33 of Set 6 | poum
# Processing Record 34 of Set 6 | necochea
# Processing Record 35 of Set 6 | khatanga
# Processing Record 36 of Set 6 | zhezkazgan
# Processing Record 37 of Set 6 | barrow
# Processing Record 38 of Set 6 | christchurch
# Processing Record 39 of Set 6 | cockburn town
# Processing Record 40 of Set 6 | totness
# Processing Record 41 of Set 6 | kloulklubed
# Processing Record 42 of Set 6 | manisa
# Processing Record 43 of Set 6 | bernay
# Processing Record 44 of Set 6 | itarema
# Processing Record 45 of Set 6 | grand gaube
# Processing Record 46 of Set 6 | saint anthony
# Processing Record 47 of Set 6 | saiha
# Processing Record 48 of Set 6 | port augusta
# Processing Record 49 of Set 6 | egvekinot
# Processing Record 50 of Set 6 | sakaiminato
# Processing Record 1 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 7 | talaya
# Processing Record 3 of Set 7 | san carlos de bariloche
# Processing Record 4 of Set 7 | hambantota
# Processing Record 5 of Set 7 | noumea
# Processing Record 6 of Set 7 | henties bay
# Processing Record 7 of Set 7 | rio grande
# Processing Record 8 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 9 of Set 7 | nemuro
# Processing Record 10 of Set 7 | lavrentiya
# Processing Record 11 of Set 7 | sola
# Processing Record 12 of Set 7 | podyuga
# Processing Record 13 of Set 7 | rincon
# Processing Record 14 of Set 7 | lokosovo
# Processing Record 15 of Set 7 | shenzhen
# Processing Record 16 of Set 7 | saint-pierre
# Processing Record 17 of Set 7 | shebunino
# Processing Record 18 of Set 7 | winslow
# Processing Record 19 of Set 7 | naze
# Processing Record 20 of Set 7 | bonavista
# Processing Record 21 of Set 7 | pangody
# Processing Record 22 of Set 7 | koutsouras
# Processing Record 23 of Set 7 | myitkyina
# Processing Record 24 of Set 7 | svetlogorsk
# Processing Record 25 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 26 of Set 7 | bhubaneswar
# Processing Record 27 of Set 7 | maksatikha
# Processing Record 28 of Set 7 | lingao
# Processing Record 29 of Set 7 | hay river
# Processing Record 30 of Set 7 | kawalu
# Processing Record 31 of Set 7 | sitka
# Processing Record 32 of Set 7 | suleja
# Processing Record 33 of Set 7 | bambous virieux
# Processing Record 34 of Set 7 | leningradskiy
# Processing Record 35 of Set 7 | teya
# Processing Record 36 of Set 7 | puerto escondido
# Processing Record 37 of Set 7 | east london
# Processing Record 38 of Set 7 | virginia beach
# Processing Record 39 of Set 7 | kashiwazaki
# Processing Record 40 of Set 7 | luderitz
# Processing Record 41 of Set 7 | karachi
# Processing Record 42 of Set 7 | opuwo
# Processing Record 43 of Set 7 | kodiak
# Processing Record 44 of Set 7 | manokwari
# Processing Record 45 of Set 7 | quelimane
# Processing Record 46 of Set 7 | charters towers
# Processing Record 47 of Set 7 | tres pontas
# Processing Record 48 of Set 7 | atyrau
# Processing Record 49 of Set 7 | balkhash
# Processing Record 50 of Set 7 | mafinga
# Processing Record 1 of Set 8 | komagane
# Processing Record 2 of Set 8 | copperas cove
# Processing Record 3 of Set 8 | shenjiamen
# Processing Record 4 of Set 8 | nalut
# Processing Record 5 of Set 8 | saint stephen
# Processing Record 6 of Set 8 | kidal
# Processing Record 7 of Set 8 | berlevag
# Processing Record 8 of Set 8 | sehithwa
# Processing Record 9 of Set 8 | carlsbad
# Processing Record 10 of Set 8 | luorong
# Processing Record 11 of Set 8 | atar
# Processing Record 12 of Set 8 | saint-joseph
# Processing Record 13 of Set 8 | manggar
# Processing Record 14 of Set 8 | horsham
# Processing Record 15 of Set 8 | baruun-urt
# Processing Record 16 of Set 8 | ambilobe
# Processing Record 17 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 8 | khvorostyanka
# Processing Record 19 of Set 8 | oranjemund
# Processing Record 20 of Set 8 | paraiso
# Processing Record 21 of Set 8 | kalaleh
# Processing Record 22 of Set 8 | mitu
# Processing Record 23 of Set 8 | dourados
# Processing Record 24 of Set 8 | birjand
# Processing Record 25 of Set 8 | shimoda
# Processing Record 26 of Set 8 | guerrero negro
# Processing Record 27 of Set 8 | melfort
# Processing Record 28 of Set 8 | plettenberg bay
# Processing Record 29 of Set 8 | broome
# Processing Record 30 of Set 8 | ziway
# Processing Record 31 of Set 8 | phayao
# Processing Record 32 of Set 8 | stavern
# Processing Record 33 of Set 8 | vestmannaeyjar
# Processing Record 34 of Set 8 | kavaratti
# Processing Record 35 of Set 8 | taoudenni
# Processing Record 36 of Set 8 | capao bonito
# Processing Record 37 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 8 | inirida
# Processing Record 39 of Set 8 | krasnoselkup
# Processing Record 40 of Set 8 | hokitika
# Processing Record 41 of Set 8 | niono
# Processing Record 42 of Set 8 | qalyub
# Processing Record 43 of Set 8 | nouadhibou
# Processing Record 44 of Set 8 | port antonio
# Processing Record 45 of Set 8 | inverness
# Processing Record 46 of Set 8 | urdzhar
# City not found. Skipping...
# Processing Record 47 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 48 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 8 | pasni
# Processing Record 50 of Set 8 | airai
# Processing Record 1 of Set 9 | hami
# Processing Record 2 of Set 9 | alofi
# Processing Record 3 of Set 9 | shablykino
# Processing Record 4 of Set 9 | galveston
# Processing Record 5 of Set 9 | champerico
# Processing Record 6 of Set 9 | vardo
# Processing Record 7 of Set 9 | fare
# Processing Record 8 of Set 9 | rosario do sul
# Processing Record 9 of Set 9 | lasa
# Processing Record 10 of Set 9 | saint george
# Processing Record 11 of Set 9 | chegdomyn
# Processing Record 12 of Set 9 | nyrob
# Processing Record 13 of Set 9 | vila velha
# Processing Record 14 of Set 9 | winnemucca
# Processing Record 15 of Set 9 | itaituba
# Processing Record 16 of Set 9 | jardim
# Processing Record 17 of Set 9 | havoysund
# Processing Record 18 of Set 9 | lambari
# Processing Record 19 of Set 9 | dingzhou
# Processing Record 20 of Set 9 | buala
# Processing Record 21 of Set 9 | shache
# Processing Record 22 of Set 9 | korla
# Processing Record 23 of Set 9 | tarauaca
# Processing Record 24 of Set 9 | sisimiut
# Processing Record 25 of Set 9 | dogondoutchi
# Processing Record 26 of Set 9 | gravdal
# Processing Record 27 of Set 9 | portland
# Processing Record 28 of Set 9 | leshukonskoye
# Processing Record 29 of Set 9 | goderich
# Processing Record 30 of Set 9 | mawlaik
# Processing Record 31 of Set 9 | port blair
# Processing Record 32 of Set 9 | souillac
# Processing Record 33 of Set 9 | manzil tamim
# City not found. Skipping...
# Processing Record 34 of Set 9 | dudinka
# Processing Record 35 of Set 9 | dawson creek
# Processing Record 36 of Set 9 | tuatapere
# Processing Record 37 of Set 9 | cabo san lucas
# Processing Record 38 of Set 9 | sao felix do xingu
# Processing Record 39 of Set 9 | faanui
# Processing Record 40 of Set 9 | east hemet
# Processing Record 41 of Set 9 | kilindoni
# Processing Record 42 of Set 9 | kashi
# Processing Record 43 of Set 9 | pafos
# Processing Record 44 of Set 9 | calvinia
# Processing Record 45 of Set 9 | itacoatiara
# Processing Record 46 of Set 9 | tanout
# Processing Record 47 of Set 9 | arzgir
# Processing Record 48 of Set 9 | along
# Processing Record 49 of Set 9 | delogozdi
# City not found. Skipping...
# Processing Record 50 of Set 9 | olinda
# Processing Record 1 of Set 10 | aykhal
# Processing Record 2 of Set 10 | matay
# Processing Record 3 of Set 10 | soyo
# Processing Record 4 of Set 10 | jaguaruna
# Processing Record 5 of Set 10 | makaryev
# Processing Record 6 of Set 10 | atikokan
# Processing Record 7 of Set 10 | mokobeng
# Processing Record 8 of Set 10 | imeni poliny osipenko
# Processing Record 9 of Set 10 | belyy yar
# Processing Record 10 of Set 10 | acapulco
# Processing Record 11 of Set 10 | san angelo
# Processing Record 12 of Set 10 | disna
# Processing Record 13 of Set 10 | santa teresa
# Processing Record 14 of Set 10 | camacha
# Processing Record 15 of Set 10 | khani
# Processing Record 16 of Set 10 | mehamn
# Processing Record 17 of Set 10 | guilin
# Processing Record 18 of Set 10 | antalaha
# Processing Record 19 of Set 10 | atambua
# Processing Record 20 of Set 10 | ostrovnoy
# Processing Record 21 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 10 | bilma
# Processing Record 23 of Set 10 | srednekolymsk
# Processing Record 24 of Set 10 | moose factory
# Processing Record 25 of Set 10 | tuban
# Processing Record 26 of Set 10 | aquiraz
# Processing Record 27 of Set 10 | yueyang
# Processing Record 28 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 29 of Set 10 | bollnas
# Processing Record 30 of Set 10 | mahenge
# Processing Record 31 of Set 10 | itaiba
# Processing Record 32 of Set 10 | temaraia
# City not found. Skipping...
# Processing Record 33 of Set 10 | port-cartier
# Processing Record 34 of Set 10 | daru
# Processing Record 35 of Set 10 | bantry
# Processing Record 36 of Set 10 | dingle
# Processing Record 37 of Set 10 | phalodi
# Processing Record 38 of Set 10 | sorland
# Processing Record 39 of Set 10 | ulaanbaatar
# Processing Record 40 of Set 10 | nago
# Processing Record 41 of Set 10 | erenhot
# Processing Record 42 of Set 10 | longyearbyen
# Processing Record 43 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 44 of Set 10 | kanye
# Processing Record 45 of Set 10 | nawa
# Processing Record 46 of Set 10 | tupik
# Processing Record 47 of Set 10 | ixtapa
# Processing Record 48 of Set 10 | deputatskiy
# Processing Record 49 of Set 10 | udachnyy
# Processing Record 50 of Set 10 | ulladulla
# Processing Record 1 of Set 11 | bilibino
# Processing Record 2 of Set 11 | la orilla
# Processing Record 3 of Set 11 | coihueco
# Processing Record 4 of Set 11 | rohatyn
# Processing Record 5 of Set 11 | nusaybin
# Processing Record 6 of Set 11 | vanimo
# Processing Record 7 of Set 11 | ewa beach
# Processing Record 8 of Set 11 | humaita
# Processing Record 9 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 10 of Set 11 | khovu-aksy
# Processing Record 11 of Set 11 | matagami
# Processing Record 12 of Set 11 | rawson
# Processing Record 13 of Set 11 | quatre cocos
# Processing Record 14 of Set 11 | lucapa
# Processing Record 15 of Set 11 | mackay
# Processing Record 16 of Set 11 | saravena
# Processing Record 17 of Set 11 | krasnoarmeyskoye
# Processing Record 18 of Set 11 | iquitos
# Processing Record 19 of Set 11 | san jeronimo
# Processing Record 20 of Set 11 | bonnyville
# Processing Record 21 of Set 11 | yar-sale
# Processing Record 22 of Set 11 | coihaique
# Processing Record 23 of Set 11 | fuyang
# Processing Record 24 of Set 11 | port lincoln
# Processing Record 25 of Set 11 | burns lake
# Processing Record 26 of Set 11 | bhadrak
# Processing Record 27 of Set 11 | fairbanks
# Processing Record 28 of Set 11 | rosamorada
# Processing Record 29 of Set 11 | port macquarie
# Processing Record 30 of Set 11 | mogadishu
# Processing Record 31 of Set 11 | edelira
# Processing Record 32 of Set 11 | maragogi
# Processing Record 33 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 35 of Set 11 | bomet
# Processing Record 36 of Set 11 | terra santa
# Processing Record 37 of Set 11 | bunia
# Processing Record 38 of Set 11 | jieshi
# Processing Record 39 of Set 11 | nizhneangarsk
# Processing Record 40 of Set 11 | tonj
# Processing Record 41 of Set 11 | harper
# Processing Record 42 of Set 11 | dukat
# Processing Record 43 of Set 11 | kyaukse
# Processing Record 44 of Set 11 | severo-kurilsk
# Processing Record 45 of Set 11 | verkhoyansk
# Processing Record 46 of Set 11 | kulhudhuffushi
# Processing Record 47 of Set 11 | mapiripan
# Processing Record 48 of Set 11 | alindao
# Processing Record 49 of Set 11 | zlatoustovsk
# City not found. Skipping...
# Processing Record 50 of Set 11 | syrskoye
# Processing Record 1 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 2 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 3 of Set 12 | tromso
# Processing Record 4 of Set 12 | half moon bay
# Processing Record 5 of Set 12 | eureka
# Processing Record 6 of Set 12 | praia
# Processing Record 7 of Set 12 | kapra
# Processing Record 8 of Set 12 | todos santos
# Processing Record 9 of Set 12 | walvis bay
# Processing Record 10 of Set 12 | tiznit
# Processing Record 11 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 12 of Set 12 | mulege
# Processing Record 13 of Set 12 | turan
# Processing Record 14 of Set 12 | tual
# Processing Record 15 of Set 12 | honjo
# Processing Record 16 of Set 12 | cruz grande
# Processing Record 17 of Set 12 | bubaque
# Processing Record 18 of Set 12 | sedelnikovo
# City not found. Skipping...
# Processing Record 19 of Set 12 | weiser
# Processing Record 20 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 12 | san quintin
# Processing Record 22 of Set 12 | belize
# Processing Record 23 of Set 12 | suining
# Processing Record 24 of Set 12 | tumalim
# Processing Record 25 of Set 12 | kayerkan
# Processing Record 26 of Set 12 | kupang
# Processing Record 27 of Set 12 | khor
# Processing Record 28 of Set 12 | luena
# Processing Record 29 of Set 12 | batagay-alyta
# Processing Record 30 of Set 12 | kamaishi
# Processing Record 31 of Set 12 | trofors
# Processing Record 32 of Set 12 | ballina
# Processing Record 33 of Set 12 | jiayuguan
# Processing Record 34 of Set 12 | sur
# Processing Record 35 of Set 12 | vuktyl
# Processing Record 36 of Set 12 | aswan
# Processing Record 37 of Set 12 | nantucket
# Processing Record 38 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 39 of Set 12 | faro
# Processing Record 40 of Set 12 | abapo
# Processing Record 41 of Set 12 | port hawkesbury
# Processing Record 42 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 43 of Set 12 | kharan
# Processing Record 44 of Set 12 | mwene-ditu
# Processing Record 45 of Set 12 | sabang
# Processing Record 46 of Set 12 | ugoofaaru
# Processing Record 47 of Set 12 | athabasca
# Processing Record 48 of Set 12 | timmins
# Processing Record 49 of Set 12 | hoyanger
# Processing Record 50 of Set 12 | trat
# Processing Record 1 of Set 13 | alice springs
# Processing Record 2 of Set 13 | isangel
# Processing Record 3 of Set 13 | terney
# Processing Record 4 of Set 13 | carnarvon
# Processing Record 5 of Set 13 | long beach
# Processing Record 6 of Set 13 | cap-aux-meules
# Processing Record 7 of Set 13 | iquique
# Processing Record 8 of Set 13 | meadow lake
# Processing Record 9 of Set 13 | batagay
# Processing Record 10 of Set 13 | aubenas
# Processing Record 11 of Set 13 | ituni
# City not found. Skipping...
# Processing Record 12 of Set 13 | hohhot
# Processing Record 13 of Set 13 | jumla
# Processing Record 14 of Set 13 | port moresby
# Processing Record 15 of Set 13 | the valley
# Processing Record 16 of Set 13 | dwarka
# Processing Record 17 of Set 13 | mumford
# Processing Record 18 of Set 13 | atasu
# Processing Record 19 of Set 13 | ilhabela
# Processing Record 20 of Set 13 | bandrele
# Processing Record 21 of Set 13 | cabanas
# Processing Record 22 of Set 13 | derbent
# Processing Record 23 of Set 13 | alihe
# Processing Record 24 of Set 13 | ligayan
# Processing Record 25 of Set 13 | bay roberts
# Processing Record 26 of Set 13 | bombay
# Processing Record 27 of Set 13 | macamic
# Processing Record 28 of Set 13 | butembo
# Processing Record 29 of Set 13 | kurilsk
# Processing Record 30 of Set 13 | rovaniemi
# Processing Record 31 of Set 13 | xam nua
# Processing Record 32 of Set 13 | arkhangelskoye
# Processing Record 33 of Set 13 | santa maria del oro
# Processing Record 34 of Set 13 | soe
# Processing Record 35 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 13 | tutoia
# Processing Record 37 of Set 13 | gibara
# Processing Record 38 of Set 13 | san patricio
# Processing Record 39 of Set 13 | nohar
# Processing Record 40 of Set 13 | mao
# Processing Record 41 of Set 13 | nuuk
# Processing Record 42 of Set 13 | sorong
# Processing Record 43 of Set 13 | khandyga
# Processing Record 44 of Set 13 | severo-yeniseyskiy
# Processing Record 45 of Set 13 | bakel
# Processing Record 46 of Set 13 | yanam
# Processing Record 47 of Set 13 | rosetta
# Processing Record 48 of Set 13 | yaan
# Processing Record 49 of Set 13 | zhigansk
# Processing Record 50 of Set 13 | dobre miasto
# Processing Record 1 of Set 14 | bagan
# Processing Record 2 of Set 14 | limon
# Processing Record 3 of Set 14 | sakakah
# Processing Record 4 of Set 14 | wasilla
# Processing Record 5 of Set 14 | kadoma
# Processing Record 6 of Set 14 | birao
# Processing Record 7 of Set 14 | arlit
# Processing Record 8 of Set 14 | saint-leu
# Processing Record 9 of Set 14 | nanpara
# Processing Record 10 of Set 14 | komsomolskiy
# Processing Record 11 of Set 14 | cumaribo
# City not found. Skipping...
# Processing Record 12 of Set 14 | inuvik
# Processing Record 13 of Set 14 | oksfjord
# Processing Record 14 of Set 14 | ous
# Processing Record 15 of Set 14 | avera
# Processing Record 16 of Set 14 | omsukchan
# Processing Record 17 of Set 14 | comodoro rivadavia
# Processing Record 18 of Set 14 | ulagan
# Processing Record 19 of Set 14 | bereda
# Processing Record 20 of Set 14 | general roca
# Processing Record 21 of Set 14 | george
# Processing Record 22 of Set 14 | puerto madryn
# Processing Record 23 of Set 14 | gizo
# Processing Record 24 of Set 14 | conde
# Processing Record 25 of Set 14 | krutikha
# Processing Record 26 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 27 of Set 14 | umm lajj
# Processing Record 28 of Set 14 | tomatlan
# Processing Record 29 of Set 14 | perth
# Processing Record 30 of Set 14 | sioux lookout
# Processing Record 31 of Set 14 | vanderhoof
# Processing Record 32 of Set 14 | bud
# Processing Record 33 of Set 14 | peto
# Processing Record 34 of Set 14 | castelo do piaui
# Processing Record 35 of Set 14 | kandrian
# Processing Record 36 of Set 14 | zhangjiakou
# Processing Record 37 of Set 14 | senekal
# Processing Record 38 of Set 14 | pahrump
# Processing Record 39 of Set 14 | faya
# Processing Record 40 of Set 14 | kruisfontein
# Processing Record 41 of Set 14 | padang
# Processing Record 42 of Set 14 | roma
# Processing Record 43 of Set 14 | huangnihe
# Processing Record 44 of Set 14 | bonoua
# Processing Record 45 of Set 14 | beringovskiy
# Processing Record 46 of Set 14 | riyadh
# Processing Record 47 of Set 14 | bandarbeyla
# Processing Record 48 of Set 14 | lata
# Processing Record 49 of Set 14 | california city
# Processing Record 50 of Set 14 | kerema
# Processing Record 1 of Set 15 | san cristobal
# Processing Record 2 of Set 15 | nisia floresta
# Processing Record 3 of Set 15 | panguna
# Processing Record 4 of Set 15 | palana
# Processing Record 5 of Set 15 | tabou
# Processing Record 6 of Set 15 | saint-felicien
# Processing Record 7 of Set 15 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 15 | shingu
# Processing Record 9 of Set 15 | skagastrond
# City not found. Skipping...
# Processing Record 10 of Set 15 | nuevo progreso
# Processing Record 11 of Set 15 | nizhnyaya tavda
# Processing Record 12 of Set 15 | broken hill
# Processing Record 13 of Set 15 | galle
# Processing Record 14 of Set 15 | tepusteca
# Processing Record 15 of Set 15 | mildura
# Processing Record 16 of Set 15 | bom jesus
# Processing Record 17 of Set 15 | hanting
# Processing Record 18 of Set 15 | odweyne
# Processing Record 19 of Set 15 | graaff-reinet
# Processing Record 20 of Set 15 | kaeo
# Processing Record 21 of Set 15 | teknaf
# Processing Record 22 of Set 15 | poya
# Processing Record 23 of Set 15 | lunglei
# Processing Record 24 of Set 15 | buon me thuot
# City not found. Skipping...
# Processing Record 25 of Set 15 | zambezi
# Processing Record 26 of Set 15 | goumeron
# Processing Record 27 of Set 15 | mount darwin
# Processing Record 28 of Set 15 | wuwei
# Processing Record 29 of Set 15 | andenes
# Processing Record 30 of Set 15 | otane
# Processing Record 31 of Set 15 | kattivakkam
# Processing Record 32 of Set 15 | kanpur
# Processing Record 33 of Set 15 | singkawang
# Processing Record 34 of Set 15 | manta
# Processing Record 35 of Set 15 | lamesa
# Processing Record 36 of Set 15 | jomalig
# City not found. Skipping...
# Processing Record 37 of Set 15 | colac
# Processing Record 38 of Set 15 | abu kamal
# Processing Record 39 of Set 15 | elizabeth city
# Processing Record 40 of Set 15 | laranjeiras do sul
# Processing Record 41 of Set 15 | livani
# Processing Record 42 of Set 15 | kyaiklat
# Processing Record 43 of Set 15 | goryachegorsk
# Processing Record 44 of Set 15 | caorle
# Processing Record 45 of Set 15 | katima mulilo
# Processing Record 46 of Set 15 | shubarshi
# Processing Record 47 of Set 15 | mahadday weyne
# City not found. Skipping...
# Processing Record 48 of Set 15 | lerwick
# Processing Record 49 of Set 15 | byron bay
# Processing Record 50 of Set 15 | amapa
# Processing Record 1 of Set 16 | lincoln
# Processing Record 2 of Set 16 | rocha
# Processing Record 3 of Set 16 | balakhta
# Processing Record 4 of Set 16 | nizhniy kuranakh
# Processing Record 5 of Set 16 | batticaloa
# Processing Record 6 of Set 16 | notodden
# Processing Record 7 of Set 16 | oussouye
# Processing Record 8 of Set 16 | zhicheng
# Processing Record 9 of Set 16 | racine
# Processing Record 10 of Set 16 | paramonga
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Punta Arenas -53.1500  -70.9167     42.91        93         100
# 1         Rikitea -23.1203 -134.9692     71.20        73          99
# 2       Geraldton -28.7667  114.6000     57.61        88         100
# 3       Sept-Iles  50.2001  -66.3821     60.80        66          20
# 4       Upernavik  72.7868  -56.1549     45.57        95         100
# ..            ...      ...       ...       ...       ...         ...
# 698      Notodden  59.5594    9.2585     60.76        77          99
# 699      Oussouye  12.4850  -16.5469     84.38        89          79
# 700      Zhicheng  30.2956  111.5047     72.86        58          98
# 701        Racine  42.7495  -88.0751     85.03        62          40
# 702     Paramonga -10.6667  -77.8333     64.99        70           6
#
#      Wind Speed Country Current Description
# 0         10.36      CL          light rain
# 1         21.54      PF     overcast clouds
# 2         18.41      AU     overcast clouds
# 3         12.66      CA          few clouds
# 4         28.86      GL          light rain
# ..          ...     ...                 ...
# 698        5.01      NO     overcast clouds
# 699        6.38      SN       broken clouds
# 700        6.22      CN     overcast clouds
# 701        9.22      US    scattered clouds
# 702       11.14      PE           clear sky
#
# [703 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
